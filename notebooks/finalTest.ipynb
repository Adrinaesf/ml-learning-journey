# %%
import torch
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print(torch.__version__)
print(torchvision.__version__)

x = [1,2,3,4]
y = [1,4,9,16]

plt.plot(x, y)
plt.title("Offline graph works")
plt.show()

from torchvision import datasets

train_data = datasets.FashionMNIST(
    root="/Users/adrina/Desktop/ML-Offline/datasets",
    train=True,
    download=False
)

print(len(train_data))
# Out:
# 2.8.0
# 0.23.0
# 60000
