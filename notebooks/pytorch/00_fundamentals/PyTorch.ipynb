# %%
'''
    * What is and Why to use pytorch?
        . Most popular research deep learning framework
        . Write fast DL in python
        . Access many pre-built deep learning models

    * Why pyTorch?
        . Very useful for the research
        . It is used in tesla, microsoft, open AI, Agriculture, ....
    
    . What is GPU/TPU?
        . GPU: Graphic Prossing Unit
        . DO a bit of research. 
    --------------------------------------------------------
    * What is a tensor?
        . A tensor is a represenation of the numbers for our data
        . There are differnt kinds of tensors. 
        . We can apply mathematical operations on these tensors.
     --------------------------------------------------------
    = 
    

'''
