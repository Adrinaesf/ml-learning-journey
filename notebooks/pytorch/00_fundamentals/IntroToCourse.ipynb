# %%
 '''
 Deep Learning with PyTorch Course
    - What is deep learning?
        - Subset of machine learning
        - ML is turning data into numbers and finding patterns in those numbers
        - The computers find these patterns using math formulas and coding

    - ML vs DL:
        - AI --> ML --> DL

    - Differnece between traditional and ML programs:
        Goal: What we should do to get the desired output? 
        
        - Traditionally we had inputs and a set of rules for them to produce 
        the desired outcome. 

        - In ML algo, we have the inputs and the desired output, and 
        we figure out the rules by finding the patterns between the input and 
        the output. (Supervised Learning)


    - Why use ML instead of traditional?
        - For a complex problem, can you think of all the rules?
        - Example: How to make a self-deriving car?
        - There are many rules, so ML, and DL is way better

    - Number one rule of ML:
        - If you can build a simple rule-based system, 
        that doesn't require ML to do that. 

    - What DL is good for? 
        1. problems with long list of rules (Like deriving)
        2. continually changing environments (It can adjust to different 
        environments, cause you can give the data and update them)
        3. Discovering insights in A LARGE LARGE dataset

    - What DL is not good for? 
        1. When you need explainity. The patterns learned by a DL model are 
        typically uninterpteable by humans. 
        2. when traditional is better
        3. when errors are unaccepteable - since the outputs of deep learning 
        aren't predicateable
        4. when you don't have that much of data

    -------------------------------------------------------------------------
    - ML vs DL
        1. In ML you have structured data --> best algo is gradient based machine
        2. In DL you have the unstructured data --> best algo is neural networks

        - Famous algorithems in ML: (Structured data)
            1. Random Forest
            2. Gradient noosted models
            3. Naive Bayes
            4. Nearest neghbour
            5. Support vector Machine
            ...

        - Famous algo in DL: (Unstructured data)
            1. Neural networks
            2. Fully connected neural networks
            3. recurrent neural networks
            4. Tranformers
            ...

        * Depedning on how you represent your data nad your problem, 
        many algo can be used for both structured AND unstructured data
    -------------------------------------------------------------------------
    - What are neural networks? 
        - we have some data (food, pictures, voices)
        - change them to numerical datas (matrix / tensors)
        - we put the input in the neural network to learn the representation
        to manipulate the patterns/features/weights
        - then we get the output in the numeriavl data again
        - Lastly it will be translated to human terms

    - Anatomy of neural networks:
        It has 3 big section: 
            1. The input layer (numerical version of our data goes here)
            2. Hidden layers (learn patterns of those data)
                So for example take a banana
                The patterns are: Being long, yellow, black dots, curvy, ...

            3. Output layer (Outputting the learned representation or predications)
                Now we output whether or not that is a banana or not. 
                Cause a banana from an image can be very different from another banana
                And that is hard for computers to recognize but not anymore. 
     - - - - - - - - - - - - - - - - - - -  - - - - - - - - - 
    - Types of learning: 
        1. Supervised learning 
            - You have lots of inputs, and the desired output
            - You have data (lots of image)
            - Labels
        2. Unsupervised and self-supervised learning
            - You only have the data
            - Finding the fundemental patterns between them 
            - It doesn't nessecay know the difference of those patterns
        3. Transfer learning
            - Taking the paterns that a model has learned
            - and transffering it to another model. 
            -  SO that our new model has a head start. 
        4. redinforcment leaning
            - (Search it up)

     -------------------------------------------------------------------------
    - What is Deep Learning is used for?
        1. Recommedations
        2. Translation (sequence to sequence) 
        3. Speech recognition (sequence to sequence) 
        3. Computer vision (Classification/Regression)
        4. NLP (natural langage processing) (figuring out spams, and finding patterns)
        (Classification/Regression) 
'''
# Out:
# "\nDeep Learning with PyTorch Course\n   - What is deep learning?\n       - Subset of machine learning\n       - ML is turning data into numbers and finding patterns in those numbers\n       - The computers find these patterns using math formulas and coding\n\n   - ML vs DL:\n       - AI --> ML --> DL\n\n   - Differnece between traditional and ML programs:\n       Goal: What we should do to get the desired output? \n       \n       - Traditionally we had inputs and a set of rules for them to produce \n       the desired outcome. \n\n       - In ML algo, we have the inputs and the desired output, and \n       we figure out the rules by finding the patterns between the input and \n       the output. (Supervised Learning)\n\n\n   - Why use ML instead of traditional?\n       - For a complex problem, can you think of all the rules?\n       - Example: How to make a self-deriving car?\n       - There are many rules, so ML, and DL is way better\n\n   - Number one rule of ML:\n       - If you
# ...
